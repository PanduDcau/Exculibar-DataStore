# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('train_data.csv')

# %%
data
# Out:
#       CategoryCode  ItemCode      DateID  DailySales
# 0       category_2    117610   11/6/2021           7
# 1       category_4    836584  11/18/2021          16
# 2       category_1    370195   1/24/2022           6
# 3       category_2    172582  10/30/2021           5
# 4       category_2   1006009  10/30/2021           5
# ...            ...       ...         ...         ...
# 19916   category_2    225259   10/4/2021           4
# 19917   category_2    111436  10/12/2021           1
# 19918   category_2   1098502   10/1/2021           1
# 19919   category_2     20824   10/1/2021           7
# 19920   category_1    371104   10/4/2021           4
#
# [19921 rows x 4 columns]

# %%
# creating a dataframe using dictionary
df = pd.DataFrame(data)
  
# using notnull() function 
df.notnull().sum()
# Out:
# CategoryCode    19921
# ItemCode        19921
# DateID          19921
# DailySales      19921
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# CategoryCode    object
# ItemCode         int64
# DateID          object
# DailySales       int64
# dtype: object

# %%
import csv,datetime
input={}
weeklySales={}

def getWeek(date):
    year=int(date.split("/")[2])
    day=int(date.split("/")[1])
    month=int(date.split("/")[0])
    weekNo=datetime.date(year, month, day).isocalendar()[1]
    return str(year)+"_"+str(weekNo)

with open('train_data.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        itemCode=row[1]
        if not itemCode == "ItemCode":
            category=row[0]
            date=row[2]
            sales=row[3]
            week=getWeek(date)
            if input.get(week) == None:
                input[week] = {itemCode:{"category":category,"sales":sales}}
            else:
                if input[week].get(itemCode) == None:
                    input[week][itemCode]={"category":category,"sales":sales}
                else:
                    existing=input[week][itemCode]["sales"]
                    totalSalesQty=int(existing)+int(sales)
                    input[week][itemCode]["sales"]=totalSalesQty
                    

print(input)
# Out:
# {'2021_44': {'117610': {'category': 'category_2', 'sales': 65}, '1067092': {'category': 'category_2', 'sales': 204}, '815101': {'category': 'category_2', 'sales': 18}, '172033': {'category': 'category_2', 'sales': 178}, '1067074': {'category': 'category_2', 'sales': 32}, '1071106': {'category': 'category_2', 'sales': 25}, '30877': {'category': 'category_2', 'sales': 72}, '877624': {'category': 'category_2', 'sales': 31}, '1098493': {'category': 'category_2', 'sales': 12}, '1048975': {'category': 'category_1', 'sales': 8}, '1075651': {'category': 'category_1', 'sales': 7}, '1061341': {'category': 'category_1', 'sales': 72}, '17287': {'category': 'category_1', 'sales': 21}, '893824': {'category': 'category_3', 'sales': 69}, '118033': {'category': 'category_2', 'sales': 11}, '1060630': {'category': 'category_3', 'sales': 46}, '1058713': {'category': 'category_1', 'sales': 34}, '837943': {'category': 'category_2', 'sales': 89}, '23569': {'category': 'category_2', 'sales': 30}, '906586': {'category': 'category_2', 'sales': 11}, '36898': {'category': 'category_1', 'sales': 74}, '262384': {'category': 'category_2', 'sales': 19}